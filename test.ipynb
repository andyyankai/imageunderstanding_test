# %%
import sys

# %%
print(sys.version)
# Out:
# 3.6.8 (default, Jan  3 2019, 03:42:36)
# [GCC 8.2.0]

# %%
#sum

import imageio
import matplotlib.pyplot as plt
im = imageio.imread('./output.png')
print(im)
tmp = 0
result = []
aa = 0
while tmp < 1000:
    aa = sum([ x[tmp][0] for x in im])
    tmp = tmp + 1
    result.append(aa)
plt.plot(result)
plt.show()
# Out:
# [[[80 80 80]
#   [81 81 81]
#   [81 81 81]
#   ...
#   [84 84 84]
#   [84 84 84]
#   [84 84 84]]
#
#  [[78 78 78]
#   [78 78 78]
#   [78 78 78]
#   ...
#   [81 81 81]
#   [81 81 81]
#   [81 81 81]]
#
#  [[72 72 72]
#   [72 72 72]
#   [73 73 73]
#   ...
#   [75 75 75]
#   [75 75 75]
#   [75 75 75]]
#
#  ...
#
#  [[15 15 15]
#   [15 15 15]
#   [13 13 13]
#   ...
#   [15 15 15]
#   [16 16 16]
#   [15 15 15]]
#
#  [[15 15 15]
#   [15 15 15]
#   [14 14 14]
#   ...
#   [15 15 15]
#   [16 16 16]
#   [15 15 15]]
#
#  [[15 15 15]
#   [15 15 15]
#   [14 14 14]
#   ...
#   [15 15 15]
#   [16 16 16]
#   [15 15 15]]]

# %%
#sum

import imageio
import matplotlib.pyplot as plt
im = imageio.imread('./1.png')
a = [[1,2, 3], [4, 5, 6], [7, 8, 9]]
print(im)
tmp = 0
result = []
aa = 0
while tmp < 1000:
    aa = sum([ x[tmp] for x in im])
    tmp = tmp + 1
    result.append(aa)
plt.plot(result)
plt.show()
# Out:
# [[100 104 100 ... 107 106 103]
#  [ 94  95  91 ...  99  97  94]
#  [ 90  90  86 ...  91  90  88]
#  ...
#  [  0  12   0 ...  12  21   0]
#  [ 10  14   0 ...   0  16   0]
#  [ 23  18   0 ...   0  13  10]]

# %%
# Out:
# [[100 104 100 ... 107 106 103]
#  [ 94  95  91 ...  99  97  94]
#  [ 90  90  86 ...  91  90  88]
#  ...
#  [  0  12   0 ...  12  21   0]
#  [ 10  14   0 ...   0  16   0]
#  [ 23  18   0 ...   0  13  10]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-59-c7067263d22b> in <module>
#      10 aa = 0
#      11 while tmp < 1000:
# ---> 12     aa = sum([ x[tmp][0] for x in im])
#      13     tmp = tmp + 1
#      14     result.append(aa)
#
# <ipython-input-59-c7067263d22b> in <listcomp>(.0)
#      10 aa = 0
#      11 while tmp < 1000:
# ---> 12     aa = sum([ x[tmp][0] for x in im])
#      13     tmp = tmp + 1
#      14     result.append(aa)
#
# IndexError: invalid index to scalar variable.

# %%
x,y = im.shape

# %%
tmp = 100
result = []
aa = 0
while tmp < 900:
    aa = sum([ x[tmp] for x in im])
    tmp = tmp + 1
    result.append(aa)
plt.plot(im)
plt.show()
im[0]
# Out:
# Array([103, 104, 102, 103, 105, 105, 103, 105, 107, 103, 106, 104, 104,
#        102, 102, 104,  99, 104, 103, 102, 108, 106, 109, 103, 106, 110,
#        101, 107, 105, 104, 104, 103, 101, 101,  98, 105, 100, 105, 103,
#        104, 109, 103, 105, 105, 103, 105, 108, 107, 107, 108, 106, 108,
#        101, 106, 105, 105, 103, 105, 105, 105, 103, 105, 103, 103, 105,
#        105, 102, 109, 112, 101, 111, 111, 108, 114, 112,  94, 100, 104,
#         98, 105, 101,  97, 104, 103, 101, 101, 103,  98, 102, 102, 102,
#        103, 101,  98, 103, 103, 103, 101, 104, 104, 104, 102, 105, 103,
#        104, 106, 106, 105, 108, 108, 105, 109, 107, 107, 108, 108, 103,
#        104, 107, 106, 104, 102, 104, 100, 100, 102,  98,  95, 101, 102,
#         99, 105, 106, 105, 106, 105, 109, 106, 107, 109, 109, 107, 102,
#        103, 102,  93, 104, 100,  98, 103, 105, 106, 106, 107, 109, 103,
#        105, 105, 104, 103,  97, 102, 104, 103,  99, 103, 108, 104, 106,
# ...

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
img = cv2.imread('1.png')
dst = cv2.fastNlMeansDenoising(img,None,30,7,21)
plt.subplot(121),plt.imshow(img)
plt.subplot(122),plt.imshow(dst)
cv2.imwrite('output.png',dst)
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('output.png',0)
edges = cv2.Canny(img,100,120)
    
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.show()
np.median(img)
# Out:
# 13.0

# %%
edges.shape
edges[699][900]
# Out:
# 0

# %%
import numpy as np
Xtr = []
Ytr = []
cb = []
c = 1
for i in range(0,700):
    for j in range(0,1000):
        if edges[i][j] != 0:
            Xtr.append(700-i)
            Ytr.append(j)
            cb.append([j,700-i])
            c = c+1

# %%
plt.scatter(Ytr, Xtr)
#we can do a regression here
len(Xtr)
# Out:
# 3043

# %%
X = cb
y = Xtr
import pandas as pd 
pd.DataFrame(cb).to_csv("data.csv")

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd
datas = pd.read_csv('data.csv') 
datas
# Out:
#       Unnamed: 0    0    1
# 0              0  337  692
# 1              1  338  692
# 2              2  338  691
# 3              3  339  690
# 4              4  983  690
# 5              5  332  689
# 6              6  339  689
# 7              7  983  689
# 8              8  324  688
# 9              9  331  688
# 10            10  332  688
# 11            11  333  688
# 12            12  334  688
# 13            13  339  688
# 14            14  983  688
# 15            15  986  688
# 16            16  323  687
# 17            17  324  687
# 18            18  325  687
# 19            19  326  687
# 20            20  329  687
# 21            21  330  687
# 22            22  331  687
# 23            23  336  687
# 24            24  339  687
# 25            25  983  687
# 26            26  986  687
# 27            27  322  686
# 28            28  323  686
# 29            29  327  686
# ...          ...  ...  ...
# 3013        3013  928  542
# 3014        3014  929  542
# ...

# %%
X = datas.iloc[:, 1:2].values
y = datas.iloc[:, 2].values

# %%
from sklearn.linear_model import LinearRegression 
lin = LinearRegression() 
  
lin.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
plt.scatter(X, y, color = 'blue') 
  
plt.plot(X, lin.predict(X), color = 'red') 
plt.title('Linear Regression') 
plt.xlabel('X') 
plt.ylabel('Y') 
  
plt.show() 
lin.predict(X).shape
# Out:
# (3043,)

# %%
from sklearn.preprocessing import PolynomialFeatures 
  
poly = PolynomialFeatures(degree = 4) 
X_poly = poly.fit_transform(X) 

poly.fit(X_poly, y) 
lin2 = LinearRegression() 
lin2.fit(X_poly, y)

print(X)
# Out:
# [[337]
#  [338]
#  [338]
#  ...
#  [ 27]
#  [ 27]
#  [ 27]]

# %%
lp = lin2.predict(poly.fit_transform(X))
plt.scatter(X, y, color = 'blue') 
plt.plot(X, lp, color = 'red') 
plt.title('Linear Regression') 
plt.xlabel('X') 
plt.ylabel('Y') 
plt.show()
# Out:
# array([[337],
#        [338],
#        [338],
#        ...,
#        [ 27],
#        [ 27],
#        [ 27]])

# %%
from matplotlib.pyplot import plot 
print(lp)
plot(lp)
# Out:
# [610.61043437 610.56976293 610.56976293 ... 614.71971891 614.71971891
#  614.71971891]

# %%
int(lin2.predict(poly.fit_transform([[800]]))[0])
# Out:
# 549

# %%
print(im)
# Out:
# [[[80 80 80]
#   [81 81 81]
#   [81 81 81]
#   ...
#   [84 84 84]
#   [84 84 84]
#   [84 84 84]]
#
#  [[78 78 78]
#   [78 78 78]
#   [78 78 78]
#   ...
#   [81 81 81]
#   [81 81 81]
#   [81 81 81]]
#
#  [[72 72 72]
#   [72 72 72]
#   [73 73 73]
#   ...
#   [75 75 75]
#   [75 75 75]
#   [75 75 75]]
#
#  ...
#
#  [[15 15 15]
#   [15 15 15]
#   [13 13 13]
#   ...
#   [15 15 15]
#   [16 16 16]
#   [15 15 15]]
#
#  [[15 15 15]
#   [15 15 15]
#   [14 14 14]
#   ...
#   [15 15 15]
#   [16 16 16]
#   [15 15 15]]
#
#  [[15 15 15]
#   [15 15 15]
#   [14 14 14]
#   ...
#   [15 15 15]
#   [16 16 16]
#   [15 15 15]]]

# %%
tmp = 0
result = []
aa = 0
while tmp < 1000:
    skin=lin2.predict(poly.fit_transform([[tmp]]))    
    aa = sum([ im[x][tmp][0] for x in range(0,int(skin[0]))])
    tmp = tmp + 1
    result.append(aa)
plt.plot(result)
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-84-ecda4beb87bf> in <module>
#       4 while tmp < 1000:
#       5     skin=lin2.predict(poly.fit_transform([[tmp]]))
# ----> 6     aa = sum([ im[x][tmp][0] for x in range(int(skin[0]),999)])
#       7     tmp = tmp + 1
#       8     result.append(aa)
#
# <ipython-input-84-ecda4beb87bf> in <listcomp>(.0)
#       4 while tmp < 1000:
#       5     skin=lin2.predict(poly.fit_transform([[tmp]]))
# ----> 6     aa = sum([ im[x][tmp][0] for x in range(int(skin[0]),999)])
#       7     tmp = tmp + 1
#       8     result.append(aa)
#
# IndexError: index 700 is out of bounds for axis 0 with size 700
